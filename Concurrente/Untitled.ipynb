# %%
import pandas as pd

# %%
data1 = pd.read_csv("subarchivo56_covid.csv")
data1
# Out:
#       2022-08-09  aa933c  2  12  16  ...  1  2021-01-14  2021-01-14.1  9999-99-99  97
# 0     2022-08-09  5c2530  1   4   2  ...  1  2021-01-19    2021-01-15  9999-99-99  97
# 1     2022-08-09  602bb0  2  12   9  ...  1  2021-01-19    2021-01-19  9999-99-99  97
# 2     2022-08-09  4cf2af  2  12   9  ...  1  2021-01-19    2021-01-16  9999-99-99  97
# 3     2022-08-09  81f5b1  1   4  15  ...  2  2021-01-19    2021-01-08  9999-99-99   2
# 4     2022-08-09  b8c2d5  2  12   7  ...  1  2021-01-18    2021-01-18  9999-99-99  97
# ...          ...     ... ..  ..  ..  ... ..         ...           ...         ...  ..
# 8573  2022-08-09  cef3a4  2  12   9  ...  1  2021-01-19    2021-01-17  9999-99-99  97
# 8574  2022-08-09  ec9ac5  1  12   5  ...  1  2021-01-19    2021-01-16  9999-99-99  97
# 8575  2022-08-09  b8e57b  1  12   9  ...  1  2021-01-13    2021-01-10  9999-99-99  97
# 8576  2022-08-09  54a581  2   4  25  ...  1  2021-01-19    2021-01-17  9999-99-99  97
# ...

# %%
data2 = pd.read_csv("subarchivo57_covid.csv")
data2
# Out:
#       2022-08-09  a00759  1   4  ...  2021-01-19  2021-01-12  9999-99-99  97
# 0     2022-08-09  86ee84  2   4  ...  2021-01-19  2021-01-16  9999-99-99  97
# 1     2022-08-09  81db02  1   6  ...  2021-01-19  2021-01-10  9999-99-99  97
# 2     2022-08-09  ade483  2  12  ...  2021-01-10  2021-01-07  9999-99-99  97
# 3     2022-08-09  d18336  2   4  ...  2021-01-19  2021-01-14  9999-99-99   2
# 4     2022-08-09  761991  2   4  ...  2021-01-19  2021-01-12  9999-99-99  97
# ...          ...     ... ..  ..  ...         ...         ...         ...  ..
# 8573  2022-08-09  c03f88  1   4  ...  2021-01-16  2021-01-10  9999-99-99   2
# 8574  2022-08-09  799eb6  2   4  ...  2021-01-19  2021-01-14  2021-01-19   2
# 8575  2022-08-09  643408  2   4  ...  2021-01-19  2021-01-19  9999-99-99  97
# 8576  2022-08-09  9fa48b  1   4  ...  2021-01-19  2021-01-15  9999-99-99  97
# 8577  2022-08-09  cb70e6  2   4  ...  2021-01-19  2021-01-12  9999-99-99  97
#
# [8578 rows x 14 columns]

# %%
import csv

# Ruta del archivo CSV
ruta_archivo = "subarchivo57_covid.csv"

# Abrir el archivo usando open
with open(ruta_archivo, mode='r', encoding='utf-8') as archivo:
    # Crear un lector de CSV
    lector_csv = csv.reader(archivo)

    # Iterar sobre cada fila del archivo
    for fila in lector_csv:
        print(fila)  # Cada fila es una lista de valores
# Out:
# ['2022-08-09', 'a00759', '1', '4', '30', '2', '30', '30', '044', '1', '2021-01-19', '2021-01-12', '9999-99-99', '97']
# ['2022-08-09', '86ee84', '2', '4', '28', '2', '28', '28', '041', '1', '2021-01-19', '2021-01-16', '9999-99-99', '97']
# ['2022-08-09', '81db02', '1', '6', '10', '1', '10', '10', '005', '1', '2021-01-19', '2021-01-10', '9999-99-99', '97']
# ['2022-08-09', 'ade483', '2', '12', '09', '2', '21', '09', '005', '1', '2021-01-10', '2021-01-07', '9999-99-99', '97']
# ['2022-08-09', 'd18336', '2', '4', '19', '1', '19', '19', '017', '2', '2021-01-19', '2021-01-14', '9999-99-99', '2']
# ['2022-08-09', '761991', '2', '4', '32', '2', '32', '32', '017', '1', '2021-01-19', '2021-01-12', '9999-99-99', '97']
# ['2022-08-09', 'd3cbe4', '2', '4', '17', '1', '17', '17', '029', '1', '2021-01-07', '2021-01-03', '9999-99-99', '97']
# ['2022-08-09', 'e4c072', '2', '12', '03', '2', '07', '03', '008', '1', '2021-01-19', '2021-01-19', '9999-99-99', '97']
# ...
